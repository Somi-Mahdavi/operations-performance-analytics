# %%
import pandas as pd 

df = pd.read_csv('D://Data-Analytics-Portfolio/contractor-operations-analytics/data/raw/customer_support_tickets.csv')
df.shape
# Out:
# (8469, 17)

# %%
df.head(5)
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %%
df.columns.to_list()
# Out:
# ['Ticket ID',
#  'Customer Name',
#  'Customer Email',
#  'Customer Age',
#  'Customer Gender',
#  'Product Purchased',
#  'Date of Purchase',
#  'Ticket Type',
#  'Ticket Subject',
#  'Ticket Description',
#  'Ticket Status',
#  'Resolution',
#  'Ticket Priority',
#  'Ticket Channel',
#  'First Response Time',
#  'Time to Resolution',
#  'Customer Satisfaction Rating']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8469 entries, 0 to 8468
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ticket ID                     8469 non-null   int64
#  1   Customer Name                 8469 non-null   object
#  2   Customer Email                8469 non-null   object
#  3   Customer Age                  8469 non-null   int64
#  4   Customer Gender               8469 non-null   object
#  5   Product Purchased             8469 non-null   object
#  6   Date of Purchase              8469 non-null   object
#  7   Ticket Type                   8469 non-null   object
#  8   Ticket Subject                8469 non-null   object
#  9   Ticket Description            8469 non-null   object
#  10  Ticket Status                 8469 non-null   object
#  11  Resolution                    2769 non-null   object
# ...

# %%
df.sample(5)
# Out:
#       Ticket ID    Customer Name             Customer Email  Customer Age  \
# 4320       4321  James Contreras      phillip06@example.net            21
# 1031       1032   Jody Rodriguez      deborah92@example.com            67
# 3477       3478     Jacob Tanner  ronaldsampson@example.org            34
# 6685       6686  Samuel Williams    drakejasmin@example.com            19
# 286         287    Richard Salas  anthonycooper@example.org            25
#
#      Customer Gender               Product Purchased Date of Purchase  \
# 4320           Other                    Google Pixel       2021-12-26
# 1031            Male                            Xbox       2021-07-29
# 3477           Other  Nintendo Switch Pro Controller       2020-12-23
# 6685            Male             Roomba Robot Vacuum       2020-06-30
# 286            Other                 Nintendo Switch       2021-10-23
#
#                Ticket Type          Ticket Subject  \
# ...

# %%
df.isna().sum()
# Out:
# Ticket ID                          0
# Customer Name                      0
# Customer Email                     0
# Customer Age                       0
# Customer Gender                    0
# Product Purchased                  0
# Date of Purchase                   0
# Ticket Type                        0
# Ticket Subject                     0
# Ticket Description                 0
# Ticket Status                      0
# Resolution                      5700
# Ticket Priority                    0
# Ticket Channel                     0
# First Response Time             2819
# Time to Resolution              5700
# Customer Satisfaction Rating    5700
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Ticket ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Ticket Type"].value_counts(dropna=False)
# Out:
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1695
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64

# %%
df["Ticket Priority"].value_counts(dropna=False)
# Out:
# Ticket Priority
# Medium      2192
# Critical    2129
# High        2085
# Low         2063
# Name: count, dtype: int64

# %%
df["Ticket Status"].value_counts(dropna=False)
# Out:
# Ticket Status
# Pending Customer Response    2881
# Open                         2819
# Closed                       2769
# Name: count, dtype: int64

# %%
df["Ticket Channel"].value_counts(dropna=False)
# Out:
# Ticket Channel
# Email           2143
# Phone           2132
# Social media    2121
# Chat            2073
# Name: count, dtype: int64

# %%
for col in df.columns:
    print(col)
# Out:
# Ticket ID
# Customer Name
# Customer Email
# Customer Age
# Customer Gender
# Product Purchased
# Date of Purchase
# Ticket Type
# Ticket Subject
# Ticket Description
# Ticket Status
# Resolution
# Ticket Priority
# Ticket Channel
# First Response Time
# Time to Resolution
# Customer Satisfaction Rating

# %%
tickets = df.copy()

columns_to_drop = ["Customer Name",
    "Customer Email",
    "Customer Age",
    "Customer Gender",
    "Date of Purchase",
    "Customer Satisfaction Rating"]

tickets = tickets.drop(columns=columns_to_drop)

# %%
tickets.columns.tolist()
# Out:
# ['Ticket ID',
#  'Product Purchased',
#  'Ticket Type',
#  'Ticket Subject',
#  'Ticket Description',
#  'Ticket Status',
#  'Resolution',
#  'Ticket Priority',
#  'Ticket Channel',
#  'First Response Time',
#  'Time to Resolution']

# %%
tickets["Product Purchased"].value_counts().head(20)
# Out:
# Product Purchased
# Canon EOS                         240
# GoPro Hero                        228
# Nest Thermostat                   225
# Amazon Echo                       221
# Philips Hue Lights                221
# LG Smart TV                       219
# Sony Xperia                       217
# Roomba Robot Vacuum               216
# Apple AirPods                     213
# LG OLED                           213
# iPhone                            212
# Sony 4K HDR TV                    210
# LG Washing Machine                208
# Garmin Forerunner                 208
# Canon DSLR Camera                 206
# Nikon D                           204
# Nintendo Switch Pro Controller    203
# Google Pixel                      203
# Fitbit Charge                     202
# Sony PlayStation                  202
# Name: count, dtype: int64

# %%
tickets["Ticket Type"].value_counts(dropna=False)
# Out:
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1695
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64

# %%
tickets["Ticket Channel"].value_counts(dropna=False)
# Out:
# Ticket Channel
# Email           2143
# Phone           2132
# Social media    2121
# Chat            2073
# Name: count, dtype: int64

# %%
tickets = tickets.drop(columns=["Product Purchased"])

# %%
tickets = tickets.drop(columns=["Ticket Type"])

# %%
tickets.columns.tolist()
# Out:
# ['Ticket ID',
#  'Ticket Subject',
#  'Ticket Description',
#  'Ticket Status',
#  'Resolution',
#  'Ticket Priority',
#  'Ticket Channel',
#  'First Response Time',
#  'Time to Resolution']

# %%
tickets[
    ["Ticket ID", "First Response Time", "Time to Resolution"]
].head(10)
# Out:
#    Ticket ID  First Response Time   Time to Resolution
# 0          1  2023-06-01 12:15:36                  NaN
# 1          2  2023-06-01 16:45:38                  NaN
# 2          3  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3          4  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4          5  2023-06-01 00:12:42  2023-06-01 19:53:42
# 5          6                  NaN                  NaN
# 6          7                  NaN                  NaN
# 7          8                  NaN                  NaN
# 8          9  2023-06-01 10:32:47                  NaN
# 9         10  2023-06-01 09:25:48                  NaN

# %%
tickets[["First Response Time" , "Time to Resolution"]].dtypes
# Out:
# First Response Time    object
# Time to Resolution     object
# dtype: object

# %%
tickets[["First Response Time", "Time to Resolution"]].isna().sum()
# Out:
# First Response Time    2819
# Time to Resolution     5700
# dtype: int64

# %%
tickets[
    ["Ticket ID", "Ticket Status", "First Response Time", "Time to Resolution"]
].head(20)
# Out:
#     Ticket ID              Ticket Status  First Response Time  \
# 0           1  Pending Customer Response  2023-06-01 12:15:36
# 1           2  Pending Customer Response  2023-06-01 16:45:38
# 2           3                     Closed  2023-06-01 11:14:38
# 3           4                     Closed  2023-06-01 07:29:40
# 4           5                     Closed  2023-06-01 00:12:42
# 5           6                       Open                  NaN
# 6           7                       Open                  NaN
# 7           8                       Open                  NaN
# 8           9  Pending Customer Response  2023-06-01 10:32:47
# 9          10  Pending Customer Response  2023-06-01 09:25:48
# 10         11                     Closed  2023-06-01 17:46:49
# 11         12                     Closed  2023-06-01 12:05:51
# 12         13  Pending Customer Response  2023-06-01 19:03:53
# 13         14  Pending Customer Response  2023-06-01 20:34:54
# ...

# %%
tickets.groupby("Ticket Status")[
    ["First Response Time", "Time to Resolution"]
].count()
# Out:
#                            First Response Time  Time to Resolution
# Ticket Status
# Closed                                    2769                2769
# Open                                         0                   0
# Pending Customer Response                 2881                   0
